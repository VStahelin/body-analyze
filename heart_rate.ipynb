# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 

data_frame = pd.read_csv('data/ACTIVITY.csv')

data_frame.query('index > 27')
# Out:
#            date  steps  distance  runDistance  calories
# 28   2022-07-28   2705      1942          436       103
# 29   2022-07-29   3776      2670          281       146
# 30   2022-07-30   1749      1248          113        66
# 31   2022-07-31   3407      2410          270       121
# 32   2022-08-01   7079      5109          344       349
# ..          ...    ...       ...          ...       ...
# 128  2022-11-06   1405       993          145        53
# 129  2022-11-07    131        93           25         5
# 130  2022-11-08   4612      3269          245       764
# 131  2022-11-09   2664      1883          239       497
# 132  2022-11-10   3274      2343          179       811
#
# [105 rows x 5 columns]

# %%
data_frame.shape
# Out:
# (133, 5)

# %%
data_frame['calories'].head(10)

# %%
data_frame.head()
# Out:
#          date  steps  distance  runDistance  calories
# 0  2021-12-20   4955      3555          257       273
# 1  2021-12-21   1112       786          103        48
# 2  2021-12-22   1314       929          108        58
# 3  2021-12-23   2190      1548          128        81
# 4  2021-12-24   4746      3355          306       190

# %%
index = [" " + str(i) for i in range(data_frame.shape[0])]

# %%
plt.plot(data_frame['date'], data_frame['calories'])

# %%
plt.plot(data_frame['date'], data_frame['calories'], '-', color='gray')
plt.xlim(28,);

# %%
data_frame['7day_rolling_avg'] = data_frame.calories.rolling(7).mean()
display(data_frame.head(10))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [1], line 1
# ----> 1 data_frame['7day_rolling_avg'] = data_frame.calories.rolling(7).mean()
#       2 display(data_frame.head(10))
#
# NameError: name 'data_frame' is not defined

# %%
after7_data_frame = data_frame.query('index > 27')
after7_data_frame['7day_rolling_avg'] = after7_data_frame.calories.rolling(7).mean()
display(after7_data_frame)

plt.figure(figsize=(30,5))
sns.lineplot(
    data=after7_data_frame,
    label="Calories rate",
    x="date",
    y="calories"
)
sns.lineplot(
    data=after7_data_frame,
    label="Calories rolling avg",
    x="date",
    y="7day_rolling_avg"
)

plt.xlabel( 'Months')
plt.ylabel('Calories') 
pos = ['2022-07-31', '2022-08-30', '2022-09-30', '2022-10-30','2022-11-30'] 
lab = ['July', 'Aug', 'Sept', 'Oct', 'Nov'] 
plt.xticks( pos, lab)
# Out:
# C:\Users\Dicks\AppData\Local\Temp\ipykernel_16056\2953018079.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after7_data_frame['7day_rolling_avg'] = after7_data_frame.calories.rolling(7).mean()
#            date  steps  distance  runDistance  calories  7day_rolling_avg
# 28   2022-07-28   2705      1942          436       103               NaN
# 29   2022-07-29   3776      2670          281       146               NaN
# 30   2022-07-30   1749      1248          113        66               NaN
# 31   2022-07-31   3407      2410          270       121               NaN
# 32   2022-08-01   7079      5109          344       349               NaN
# ..          ...    ...       ...          ...       ...               ...
# ...
